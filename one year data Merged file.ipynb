# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\builduser\\Desktop\\oneyeardataMergedfile.csv')
df
# Out:
#          Unnamed: 0  timestamp  pCut::Motor_Torque  \
# 0                 0   0.008000            0.199603
# 1                 1   0.012000            0.281624
# 2                 2   0.016000            0.349315
# 3                 3   0.020000            0.444450
# 4                 4   0.024000            0.480923
# ...             ...        ...                 ...
# 1062907     1062907   8.179999           -0.277697
# 1062908     1062908   8.183999           -0.285098
# 1062909     1062909   8.187999           -0.155192
# 1062910     1062910   8.191999           -0.371426
# 1062911     1062911   8.195999           -0.284030
#
#          pCut::CTRL_Position_controller::Lag_error  \
# 0                                         0.027420
# 1                                         0.002502
# 2                                        -0.018085
# 3                                        -0.054680
# 4                                        -0.042770
# ...

# %%
df.drop(columns=['Unnamed: 0'])
# Out:
#          timestamp  pCut::Motor_Torque  \
# 0         0.008000            0.199603
# 1         0.012000            0.281624
# 2         0.016000            0.349315
# 3         0.020000            0.444450
# 4         0.024000            0.480923
# ...            ...                 ...
# 1062907   8.179999           -0.277697
# 1062908   8.183999           -0.285098
# 1062909   8.187999           -0.155192
# 1062910   8.191999           -0.371426
# 1062911   8.195999           -0.284030
#
#          pCut::CTRL_Position_controller::Lag_error  \
# 0                                         0.027420
# 1                                         0.002502
# 2                                        -0.018085
# 3                                        -0.054680
# 4                                        -0.042770
# ...                                            ...
# 1062907                                  -0.023948
# 1062908                                  -0.022138
# ...

# %%
a = df.iloc[:: 20, 0]

# %%
b = df.iloc[:: 20, 1]

# %%
c = df.iloc[:: 20, 2]

# %%
d = df.iloc[:: 20, 3]

# %%
e = df.iloc[:: 20, 4]

# %%
f = df.iloc[:: 20, 5]

# %%
g = df.iloc[:: 20, 6]

# %%
h = df.iloc[:: 20, 7]

# %%
i = df.iloc[:: 20, 8]

# %%
plt.figure(figsize=(15, 7))
plt.plot(a, b)
plt.title('One year data')
plt.xlabel('timestamp')
plt.ylabel('pCut::Motor_Torque')
plt.grid(True)
plt.show()

# %%
f = plt.figure()
f.clear()
plt.close(f)

# %%
plt.figure(figsize=(15, 7))
plt.plot(a, b)
plt.title('One year data')
plt.xlabel('timestamp')
plt.ylabel('pCut::Motor_Torque')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(c, b)
plt.title('One year data')
plt.xlabel('timestamp')
plt.ylabel('pCut::Motor_Torque')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(d, b)
plt.title('One year data')
plt.xlabel('timestamp')
plt.ylabel('pCut::Motor_Torque')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(e, b)
plt.title('One year data')
plt.xlabel('timestamp')
plt.ylabel('pCut::Motor_Torque')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(f, b)
plt.title('One year data')
plt.xlabel('timestamp')
plt.ylabel('pCut::Motor_Torque')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-f639da89339a> in <module>
#       1 plt.figure(figsize=(15, 7))
# ----> 2 plt.plot(f, b)
#       3 plt.title('One year data')
#       4 plt.xlabel('timestamp')
#       5 plt.ylabel('pCut::Motor_Torque')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# ...

# %%
plt.figure(figsize=(15, 7))
plt.plot(g, b)
plt.title('One year data')
plt.xlabel('timestamp')
plt.ylabel('pCut::Motor_Torque')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(h, b)
plt.title('One year data')
plt.xlabel('timestamp')
plt.ylabel('pCut::Motor_Torque')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(i, b)
plt.title('One year data')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(i, c)
plt.title('One year data')
plt.grid(True)
plt.show()
